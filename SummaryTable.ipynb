# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np

# %% [markdown]
# ## NIH Summary table

# %%
NIH_sex = pd.read_csv("./NIH/results/WantX.csv")

# %%
round(NIH_sex,3)
# Out:
#     Unnamed: 0            diseases diseases_abbr  Distance     %M  Gap_M_mean  \
# 0            9                Mass             M     0.001  0.521       0.000
# 1            4            Effusion            Ef     0.009  0.508       0.004
# 2            6            Fibrosis            Fb     0.031  0.495       0.015
# 3           13        Pneumothorax            Px     0.093  0.550      -0.047
# 4            8        Infiltration            In     0.116  0.557      -0.058
# 5           10              Nodule             N     0.157  0.544       0.079
# 6           12           Pneumonia            Pa     0.201  0.431       0.100
# 7            0         Atelectasis            At     0.240  0.609       0.120
# 8           11  Pleural_Thickening            PT     0.252  0.575      -0.126
# 9            5           Emphysema            Em     0.262  0.618       0.131
# 10           3               Edema            Ed     0.286  0.430      -0.143
# 11           7              Hernia             H     0.307  0.115      -0.154
# 12           2       Consolidation            Co     0.311  0.543       0.155
# 13           1        Cardiomegaly            Cd     0.393  0.639      -0.197
#
#      CI_M     %F  Gap_F_mean   CI_F
# 0   0.017  0.479      -0.000  0.017
# 1   0.029  0.492      -0.004  0.029
# 2   0.057  0.505      -0.015  0.057
# 3   0.045  0.450       0.047  0.045
# 4   0.020  0.443       0.058  0.020
# 5   0.037  0.456      -0.079  0.037
# 6   0.054  0.569      -0.100  0.054
# 7   0.010  0.391      -0.120  0.010
# 8   0.013  0.425       0.126  0.013
# 9   0.056  0.382      -0.131  0.056
# 10  0.035  0.570       0.143  0.035
# 11  0.110  0.885       0.154  0.110
# 12  0.037  0.457      -0.155  0.037
# 13  0.049  0.361       0.197  0.049

# %%
print("Average Distance:", round(NIH_sex["Distance"].mean(),3))
print("Count female with negative gap:",len(NIH_sex.loc[(NIH_sex.Gap_F_mean < 0)]))
print("Count male with negative gap  :",len(NIH_sex.loc[(NIH_sex.Gap_M_mean < 0)]))
print("------------------------------")
print("Count female with Positive gap:",len(NIH_sex.loc[(NIH_sex.Gap_F_mean >= 0)]))
print("Count male with Positive gap  :",len(NIH_sex.loc[(NIH_sex.Gap_M_mean >= 0)]))
# Out:
# Average Distance: 0.19
# Count female with negative gap: 8
# Count male with negative gap  : 6
# ------------------------------
# Count female with Positive gap: 6
# Count male with Positive gap  : 8

# %%
NIH_Age = pd.read_csv("./NIH/results/WantAge.csv")
round(NIH_Age,3)
# Out:
#     Unnamed: 0            diseases diseases_abbr  Distance  %40-60  \
# 0            8        Infiltration            In     0.188   0.474
# 1           11  Pleural_Thickening            PT     0.200   0.392
# 2            7              Hernia             H     0.231   0.500
# 3            4            Effusion            Ef     0.314   0.459
# 4           12           Pneumonia            Pa     0.340   0.446
# 5            9                Mass             M     0.357   0.442
# 6           13        Pneumothorax            Px     0.392   0.391
# 7            2       Consolidation            Co     0.393   0.437
# 8            1        Cardiomegaly            Cd     0.400   0.489
# 9            0         Atelectasis            At     0.415   0.469
# 10           3               Edema            Ed     0.453   0.556
# 11           6            Fibrosis            Fb     0.500   0.543
# 12          10              Nodule             N     0.603   0.546
# 13           5           Emphysema            Em     1.000   0.331
#
#     Gap_40-60_mean  CI_40-60  %60-80  Gap_60-80_mean  CI_60-80  %20-40  \
# 0            0.011     0.015   0.240           0.011     0.010   0.209
# 1            0.015     0.026   0.320          -0.067     0.034   0.221
# 2           -0.105     0.130   0.269           0.068     0.088   0.000
# 3            0.003     0.028   0.280           0.014     0.017   0.176
# 4           -0.023     0.027   0.231          -0.049     0.035   0.292
# 5            0.012     0.033   0.265           0.002     0.006   0.242
# 6            0.075     0.038   0.152          -0.075     0.038   0.397
# 7           -0.127     0.017   0.259           0.025     0.015   0.190
# 8            0.131     0.111   0.241          -0.118     0.105   0.226
# 9           -0.057     0.034   0.316           0.054     0.027   0.158
# 10           0.034     0.030   0.304          -0.060     0.034   0.126
# 11          -0.058     0.045   0.238           0.017     0.034   0.190
# 12          -0.002     0.004   0.210          -0.036     0.046   0.167
# 13           0.053     0.033   0.324          -0.099     0.046   0.331
#
#     Gap_20-40_mean  CI_20-40   %80-  Gap_80-_mean  CI_80-  %0-20  \
# 0           -0.075     0.017  0.014        -0.064   0.046  0.064
# 1            0.028     0.030  0.011        -0.167   0.159  0.055
# 2              NaN       NaN  0.231         0.125   0.274  0.000
# 3            0.002     0.004  0.016        -0.301   0.042  0.069
# 4            0.012     0.020  0.000           NaN     NaN  0.031
# 5           -0.107     0.035  0.011        -0.043   0.102  0.039
# 6            0.146     0.041  0.000           NaN     NaN  0.060
# 7            0.015     0.021  0.004        -0.334   0.020  0.109
# 8            0.153     0.087  0.023         0.020   0.137  0.023
# 9           -0.011     0.016  0.012         0.358   0.062  0.046
# 10           0.064     0.032  0.000           NaN     NaN  0.015
# 11           0.027     0.059  0.019         0.277   0.041  0.010
# 12          -0.047     0.017  0.003         0.556   0.029  0.074
# 13           0.000     0.000  0.007        -0.444   0.014  0.007
#
#     Gap_0-20_mean  CI_0-20
# 0           0.113    0.021
# 1           0.033    0.095
# 2             NaN      NaN
# 3          -0.025    0.071
# 4           0.291    0.105
# 5           0.249    0.132
# 6          -0.246    0.132
# 7           0.058    0.045
# 8          -0.247    0.154
# 9          -0.014    0.019
# 10         -0.389    0.203
# 11         -0.223    0.041
# 12          0.063    0.014
# 13          0.556    0.014

# %%
print("Average Distance:",round(NIH_Age["Distance"].mean(),3))
print("Count 40-60 with negative gap:",len(NIH_Age.loc[(NIH_Age['Gap_40-60_mean'] < 0)]))
print("Count 60-80 with negative gap:",len(NIH_Age.loc[(NIH_Age['Gap_60-80_mean'] < 0)]))
print("Count 20-40 with negative gap:",len(NIH_Age.loc[(NIH_Age['Gap_20-40_mean'] < 0)]))
print("Count 80- with negative gap:",len(NIH_Age.loc[(NIH_Age['Gap_80-_mean'] < 0)]))
print("Count 0-20 with negative gap:",len(NIH_Age.loc[(NIH_Age['Gap_0-20_mean'] < 0)]))
print("--------------------------------")
print("Count 40-60 with Positive gap:",len(NIH_Age.loc[(NIH_Age['Gap_40-60_mean'] >= 0)]))
print("Count 60-80 with Positive gap:",len(NIH_Age.loc[(NIH_Age['Gap_60-80_mean'] >= 0)]))
print("Count 20-40 with Positive gap:",len(NIH_Age.loc[(NIH_Age['Gap_20-40_mean'] >= 0)]))
print("Count 80- with Positive gap:",len(NIH_Age.loc[(NIH_Age['Gap_80-_mean'] >= 0)]))
print("Count 0-20 with Positive gap:",len(NIH_Age.loc[(NIH_Age['Gap_0-20_mean'] >= 0)]))
# Out:
# Average Distance: 0.413
# Count 40-60 with negative gap: 6
# Count 60-80 with negative gap: 7
# Count 20-40 with negative gap: 4
# Count 80- with negative gap: 6
# Count 0-20 with negative gap: 6
# --------------------------------
# Count 40-60 with Positive gap: 8
# Count 60-80 with Positive gap: 7
# Count 20-40 with Positive gap: 9
# Count 80- with Positive gap: 5
# Count 0-20 with Positive gap: 7

# %% [markdown]
# ## CXP Summary table

# %%
CXP_sex = pd.read_csv("./CXP/results/WantX.csv")

# %%
round(CXP_sex,3)
# Out:
#     Unnamed: 0                    diseases diseases_abbr  Distance     %M  \
# 0            3                       Edema            Ed     0.000  0.566
# 1           11                   Pneumonia            Pa     0.004  0.582
# 2            5                    Fracture            Fr     0.013  0.711
# 3           13             Support Devices            SD     0.015  0.593
# 4            0                 Atelectasis             A     0.027  0.599
# 5            7                Lung Opacity            AO     0.042  0.593
# 6            6                 Lung Lesion            LL     0.047  0.553
# 7            9            Pleural Effusion            Ef     0.054  0.583
# 8           12                Pneumothorax            Px     0.064  0.648
# 9           10               Pleural Other            PO     0.092  0.721
# 10           8                  No Finding            NF     0.113  0.577
# 11           4  Enlarged Cardiomediastinum            EC     0.125  0.610
# 12           1                Cardiomegaly            Cd     0.128  0.608
# 13           2               Consolidation            Co     0.139  0.573
#
#     Gap_M_mean   CI_M     %F  Gap_F_mean   CI_F
# 0       -0.000  0.010  0.434       0.000  0.010
# 1        0.002  0.008  0.418      -0.002  0.008
# 2       -0.007  0.016  0.289       0.007  0.016
# 3       -0.007  0.005  0.407       0.007  0.005
# 4        0.013  0.015  0.401      -0.013  0.015
# 5       -0.021  0.006  0.407       0.021  0.006
# 6        0.024  0.018  0.447      -0.024  0.018
# 7       -0.027  0.011  0.417       0.027  0.011
# 8        0.032  0.018  0.352      -0.032  0.018
# 9        0.046  0.027  0.279      -0.046  0.027
# 10      -0.057  0.011  0.423       0.057  0.011
# 11       0.062  0.018  0.390      -0.062  0.018
# 12       0.064  0.023  0.392      -0.064  0.023
# 13      -0.070  0.014  0.427       0.070  0.014

# %%
print("Average Distance:",round(CXP_sex["Distance"].mean(),3))
print("Count female with negative gap:",len(CXP_sex.loc[(CXP_sex.Gap_F_mean < 0)]))
print("Count male with negative gap  :",len(CXP_sex.loc[(CXP_sex.Gap_M_mean < 0)])-1) # -1 is to exclude No Finding as it is not a disease
print("-------------------------------------------")
print("Count female with positive gap:",len(CXP_sex.loc[(CXP_sex.Gap_F_mean >= 0)])-1)#-1 is to exclude No Finding as it is not a disease
print("Count male with positive gap  :",len(CXP_sex.loc[(CXP_sex.Gap_M_mean >= 0)])) #
# Out:
# Average Distance: 0.062
# Count female with negative gap: 7
# Count male with negative gap  : 6
# -------------------------------------------
# Count female with positive gap: 6
# Count male with positive gap  : 7

# %%
CXP_Age = pd.read_csv("./CXP/results/WantAge.csv")
round(CXP_Age,3)
# Out:
#     Unnamed: 0                    diseases diseases_abbr  Distance  %40-60  \
# 0           13             Support Devices            SD     0.084   0.323
# 1            3                       Edema            Ed     0.107   0.269
# 2            9            Pleural Effusion            Ef     0.141   0.298
# 3            7                Lung Opacity            AO     0.142   0.290
# 4            1                Cardiomegaly            Cd     0.163   0.247
# 5           12                Pneumothorax            Px     0.186   0.289
# 6            4  Enlarged Cardiomediastinum            EC     0.204   0.288
# 7            0                 Atelectasis             A     0.249   0.327
# 8           11                   Pneumonia            Pa     0.307   0.281
# 9            6                 Lung Lesion            LL     0.323   0.265
# 10           2               Consolidation            Co     0.357   0.319
# 11           5                    Fracture            Fr     0.454   0.308
# 12          10               Pleural Other            PO     0.460   0.250
# 13           8                  No Finding            NF     0.604   0.388
#
#     Gap_40-60_mean  CI_40-60  %60-80  Gap_60-80_mean  CI_60-80  %20-40  \
# 0            0.000     0.000   0.399          -0.022     0.002   0.131
# 1           -0.001     0.003   0.423           0.050     0.008   0.082
# 2            0.004     0.007   0.420           0.013     0.007   0.093
# 3            0.000     0.000   0.407           0.039     0.006   0.108
# 4            0.016     0.009   0.400          -0.001     0.002   0.112
# 5           -0.019     0.016   0.418          -0.000     0.000   0.185
# 6            0.007     0.012   0.403          -0.007     0.009   0.128
# 7            0.063     0.015   0.421           0.030     0.021   0.084
# 8           -0.058     0.016   0.373           0.000     0.000   0.121
# 9            0.000     0.000   0.421           0.080     0.015   0.134
# 10          -0.019     0.017   0.364          -0.060     0.030   0.123
# 11           0.069     0.037   0.344          -0.121     0.027   0.125
# 12          -0.005     0.009   0.362           0.058     0.022   0.160
# 13           0.019     0.015   0.273          -0.210     0.015   0.261
#
#     Gap_20-40_mean  CI_20-40   %80-  Gap_80-_mean  CI_80-  %0-20  \
# 0            0.006     0.003  0.136        -0.039   0.008  0.010
# 1           -0.030     0.010  0.219         0.072   0.011  0.007
# 2           -0.057     0.015  0.183         0.004   0.003  0.007
# 3           -0.046     0.012  0.188         0.077   0.006  0.008
# 4           -0.019     0.016  0.236        -0.049   0.026  0.005
# 5            0.068     0.018  0.092        -0.119   0.028  0.016
# 6            0.050     0.032  0.170         0.013   0.020  0.010
# 7           -0.012     0.022  0.160        -0.022   0.032  0.008
# 8            0.105     0.054  0.204        -0.026   0.015  0.021
# 9           -0.105     0.025  0.179         0.017   0.023  0.001
# 10           0.013     0.012  0.180         0.011   0.031  0.014
# 11          -0.043     0.042  0.216        -0.029   0.036  0.006
# 12           0.337     0.034  0.218        -0.037   0.039  0.010
# 13           0.123     0.016  0.060        -0.481   0.048  0.018
#
#     Gap_0-20_mean  CI_0-20
# 0           0.045    0.012
# 1          -0.034    0.028
# 2          -0.129    0.035
# 3          -0.065    0.020
# 4           0.114    0.036
# 5           0.051    0.036
# 6          -0.154    0.031
# 7          -0.186    0.054
# 8           0.248    0.103
# 9          -0.244    0.018
# 10          0.297    0.062
# 11          0.333    0.205
# 12         -0.123    0.034
# 13          0.006    0.012

# %%
CXP_Age.iloc[13]
# Out:
# Unnamed: 0                 8
# diseases          No Finding
# diseases_abbr             NF
# Distance            0.603613
# %40-60              0.388086
# Gap_40-60_mean     0.0193593
# CI_40-60           0.0151588
# %60-80              0.273325
# Gap_60-80_mean     -0.209941
# CI_60-80           0.0150005
# %20-40              0.260622
# Gap_20-40_mean       0.12282
# CI_20-40           0.0157532
# %80-               0.0595707
# Gap_80-_mean       -0.480793
# CI_80-             0.0477343
# %0-20              0.0183968
# Gap_0-20_mean     0.00590132
# CI_0-20            0.0115666
# Name: 13, dtype: object

# %%
print("Average Distance:",round(CXP_Age["Distance"].mean(),3))
print("Count 40-60 with negative gap:",len(CXP_Age.loc[(CXP_Age['Gap_40-60_mean'] < 0)]))
print("Count 60-80 with negative gap:",len(CXP_Age.loc[(CXP_Age['Gap_60-80_mean'] < 0)])-1)
print("Count 20-40 with negative gap:",len(CXP_Age.loc[(CXP_Age['Gap_20-40_mean'] < 0)]))
print("Count 80- with negative gap:",len(CXP_Age.loc[(CXP_Age['Gap_80-_mean'] < 0)])-1)
print("Count 0-20 with negative gap:",len(CXP_Age.loc[(CXP_Age['Gap_0-20_mean'] < 0)]))
print("------------------------------------------")
print("Count 40-60 with positive gap:",len(CXP_Age.loc[(CXP_Age['Gap_40-60_mean'] >= 0)])-1)
print("Count 60-80 with positive gap:",len(CXP_Age.loc[(CXP_Age['Gap_60-80_mean'] >= 0)]))
print("Count 20-40 with positive gap:",len(CXP_Age.loc[(CXP_Age['Gap_20-40_mean'] >= 0)])-1)
print("Count 80- with positive gap:",len(CXP_Age.loc[(CXP_Age['Gap_80-_mean'] >= 0)]))
print("Count 0-20 with positive gap:",len(CXP_Age.loc[(CXP_Age['Gap_0-20_mean'] >= 0)])-1)
# Out:
# Average Distance: 0.27
# Count 40-60 with negative gap: 5
# Count 60-80 with negative gap: 6
# Count 20-40 with negative gap: 7
# Count 80- with negative gap: 7
# Count 0-20 with negative gap: 7
# ------------------------------------------
# Count 40-60 with positive gap: 8
# Count 60-80 with positive gap: 7
# Count 20-40 with positive gap: 6
# Count 80- with positive gap: 6
# Count 0-20 with positive gap: 6

# %% [markdown]
# ## CXR Summary table

# %%
MIMIC_sex = pd.read_csv("./MIMIC/results/WantX.csv")

# %%
round(MIMIC_sex,3)
# Out:
#     Unnamed: 0                    diseases diseases_abbr  Distance     %M  \
# 0           12                Pneumothorax            Px     0.017  0.666
# 1            1                 Atelectasis             A     0.025  0.607
# 2           10               Pleural Other            PO     0.029  0.653
# 3            4                       Edema            Ed     0.034  0.565
# 4            2                Cardiomegaly            Cd     0.056  0.592
# 5            3               Consolidation            Co     0.091  0.630
# 6            7                 Lung Lesion            LL     0.101  0.571
# 7            0            Airspace Opacity            AO     0.118  0.621
# 8           11                   Pneumonia            Pa     0.128  0.592
# 9            6                    Fracture            Fr     0.129  0.663
# 10           5  Enlarged Cardiomediastinum            EC     0.157  0.619
# 11           9            Pleural Effusion            Ef     0.184  0.551
# 12          13             Support Devices            SD     0.284  0.655
# 13           8                  No Finding            NF     0.369  0.465
#
#     Gap_M_mean   CI_M     %F  Gap_F_mean   CI_F
# 0        0.008  0.011  0.334      -0.008  0.011
# 1       -0.012  0.008  0.393       0.012  0.008
# 2        0.015  0.034  0.347      -0.015  0.034
# 3        0.017  0.017  0.435      -0.017  0.017
# 4        0.028  0.014  0.408      -0.028  0.014
# 5        0.045  0.013  0.370      -0.045  0.013
# 6       -0.051  0.009  0.429       0.051  0.009
# 7        0.059  0.012  0.379      -0.059  0.012
# 8        0.064  0.014  0.408      -0.064  0.014
# 9        0.065  0.009  0.337      -0.065  0.009
# 10       0.079  0.008  0.381      -0.079  0.008
# 11      -0.092  0.012  0.449       0.092  0.012
# 12       0.142  0.005  0.345      -0.142  0.005
# 13      -0.185  0.008  0.535       0.185  0.008

# %%
print("Average Distance:",round(MIMIC_sex["Distance"].mean(),3))
print("Count female with negative gap:",len(MIMIC_sex.loc[(MIMIC_sex.Gap_F_mean < 0)]))
print("Count male with negative gap  :",len(MIMIC_sex.loc[(MIMIC_sex.Gap_M_mean < 0)])-1) # -1 is to exclude No Finding as it is not a disease
print("--------------------------")
print("Count female with Positive gap:",len(MIMIC_sex.loc[(MIMIC_sex.Gap_F_mean >= 0)])-1)
print("Count male with Positive gap  :",len(MIMIC_sex.loc[(MIMIC_sex.Gap_M_mean >= 0)])) # -1 is to exclude No Finding as it is not a disease
# Out:
# Average Distance: 0.123
# Count female with negative gap: 10
# Count male with negative gap  : 3
# --------------------------
# Count female with Positive gap: 3
# Count male with Positive gap  : 10

# %%
MIMIC_Age = pd.read_csv("./MIMIC/results/WantAge.csv")
round(MIMIC_Age,3)
# Out:
#     Unnamed: 0                    diseases diseases_abbr  Distance  %40-60  \
# 0           11                   Pneumonia            Pa     0.054   0.362
# 1            3               Consolidation            Co     0.059   0.373
# 2            7                 Lung Lesion            LL     0.089   0.391
# 3           10               Pleural Other            PO     0.156   0.476
# 4            6                    Fracture            Fr     0.170   0.450
# 5            5  Enlarged Cardiomediastinum            EC     0.235   0.350
# 6            0            Airspace Opacity            AO     0.246   0.365
# 7           13             Support Devices            SD     0.326   0.328
# 8           12                Pneumothorax            Px     0.363   0.318
# 9            1                 Atelectasis             A     0.374   0.336
# 10           2                Cardiomegaly            Cd     0.386   0.320
# 11           9            Pleural Effusion            Ef     0.401   0.283
# 12           8                  No Finding            NF     0.497   0.389
# 13           4                       Edema            Ed     0.544   0.315
#
#     Gap_40-60_mean  CI_40-60  %60-80  Gap_60-80_mean  CI_60-80  %20-40  \
# 0            0.025     0.014   0.433          -0.008     0.010   0.138
# 1           -0.037     0.011   0.417           0.022     0.025   0.148
# 2            0.044     0.014   0.451           0.044     0.007   0.095
# 3            0.032     0.019   0.431           0.046     0.017   0.030
# 4            0.014     0.014   0.383          -0.023     0.014   0.087
# 5           -0.048     0.007   0.451           0.040     0.012   0.143
# 6           -0.001     0.003   0.407           0.098     0.007   0.154
# 7           -0.104     0.003   0.396           0.000     0.000   0.221
# 8            0.000     0.000   0.364          -0.081     0.012   0.243
# 9            0.000     0.000   0.479           0.162     0.008   0.130
# 10          -0.087     0.022   0.415           0.000     0.000   0.196
# 11           0.000     0.000   0.513           0.130     0.009   0.119
# 12           0.000     0.000   0.230          -0.203     0.007   0.342
# 13           0.000     0.000   0.418          -0.015     0.007   0.181
#
#     Gap_20-40_mean  CI_20-40   %80-  Gap_80-_mean  CI_80-  %0-20  \
# 0           -0.020     0.019  0.057         0.020   0.024  0.010
# 1            0.013     0.008  0.059        -0.032   0.047  0.003
# 2           -0.007     0.009  0.042        -0.019   0.026  0.021
# 3           -0.111     0.042  0.064        -0.026   0.014  0.000
# 4           -0.067     0.018  0.075         0.004   0.009  0.006
# 5           -0.004     0.006  0.046        -0.012   0.014  0.010
# 6           -0.008     0.008  0.065         0.130   0.021  0.009
# 7            0.130     0.006  0.050         0.085   0.008  0.005
# 8            0.164     0.024  0.056        -0.169   0.015  0.019
# 9           -0.050     0.015  0.050         0.138   0.021  0.005
# 10           0.126     0.020  0.066         0.106   0.003  0.003
# 11          -0.137     0.026  0.080         0.161   0.006  0.007
# 12           0.231     0.007  0.023        -0.266   0.012  0.017
# 13           0.119     0.025  0.085         0.160   0.020  0.001
#
#     Gap_0-20_mean  CI_0-20
# 0          -0.028    0.050
# 1           0.003    0.016
# 2          -0.045    0.028
# 3             NaN      NaN
# 4           0.103    0.051
# 5           0.187    0.038
# 6          -0.116    0.035
# 7          -0.196    0.027
# 8           0.194    0.071
# 9          -0.211    0.016
# 10         -0.260    0.032
# 11         -0.240    0.024
# 12          0.211    0.007
# 13         -0.383    0.034

# %%
MIMIC_Age.iloc[12]
# Out:
# Unnamed: 0                 8
# diseases          No Finding
# diseases_abbr             NF
# Distance            0.497037
# %40-60              0.388711
# Gap_40-60_mean             0
# CI_40-60                   0
# %60-80              0.229541
# Gap_60-80_mean     -0.202692
# CI_60-80          0.00723827
# %20-40              0.342052
# Gap_20-40_mean      0.231414
# CI_20-40          0.00717746
# %80-               0.0228413
# Gap_80-_mean       -0.265623
# CI_80-             0.0115276
# %0-20              0.0168543
# Gap_0-20_mean       0.210916
# CI_0-20           0.00675574
# Name: 12, dtype: object

# %%
print("Average Distance:",round(MIMIC_Age["Distance"].mean(),3))
print("Count 40-60 with negative gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_40-60_mean'] < 0)]))
print("Count 60-80 with negative gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_60-80_mean'] < 0)])-1)
print("Count 20-40 with negative gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_20-40_mean'] < 0)]))
print("Count 80- with negative gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_80-_mean'] < 0)])-1)
print("Count 0-20 with negative gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_0-20_mean'] < 0)]))
print("----------------------------------------------")
print("Count 40-60 with positive gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_40-60_mean'] >= 0)])-1)
print("Count 60-80 with positive gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_60-80_mean'] >= 0)]))
print("Count 20-40 with positive gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_20-40_mean'] >= 0)])-1)
print("Count 80- with positive gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_80-_mean'] >= 0)]))
print("Count 0-20 with positive gap:",len(MIMIC_Age.loc[(MIMIC_Age['Gap_0-20_mean'] >= 0)])-1)
# Out:
# Average Distance: 0.279
# Count 40-60 with negative gap: 5
# Count 60-80 with negative gap: 4
# Count 20-40 with negative gap: 8
# Count 80- with negative gap: 5
# Count 0-20 with negative gap: 8
# ----------------------------------------------
# Count 40-60 with positive gap: 8
# Count 60-80 with positive gap: 9
# Count 20-40 with positive gap: 5
# Count 80- with positive gap: 8
# Count 0-20 with positive gap: 4

# %%
MIMIC_race = pd.read_csv("./MIMIC/results/WantR.csv")
round(MIMIC_race,3)
# Out:
#     Unnamed: 0                    diseases diseases_abbr  Distance  %White  \
# 0           12                Pneumothorax            Px     0.094   0.751
# 1            1                 Atelectasis             A     0.114   0.661
# 2            3               Consolidation            Co     0.129   0.715
# 3           10               Pleural Other            PO     0.167   0.937
# 4            4                       Edema            Ed     0.178   0.618
# 5            6                    Fracture            Fr     0.211   0.812
# 6            2                Cardiomegaly            Cd     0.224   0.585
# 7            5  Enlarged Cardiomediastinum            EC     0.251   0.703
# 8           13             Support Devices            SD     0.287   0.618
# 9           11                   Pneumonia            Pa     0.297   0.672
# 10           8                  No Finding            NF     0.298   0.502
# 11           7                 Lung Lesion            LL     0.305   0.716
# 12           9            Pleural Effusion            Ef     0.353   0.710
# 13           0            Airspace Opacity            AO     0.361   0.675
#
#     Gap_W_mean   CI_W  %Black  Gap_B_mean   CI_B  ...   CI_H  %Other  \
# 0        0.040  0.024   0.127      -0.054  0.016  ...  0.013   0.029
# 1        0.000  0.008   0.201      -0.027  0.011  ...  0.009   0.037
# 2        0.062  0.034   0.149      -0.007  0.009  ...  0.016   0.023
# 3        0.140  0.029   0.048       0.000  0.000  ...  0.004   0.005
# 4       -0.002  0.007   0.204       0.015  0.014  ...  0.013   0.038
# 5        0.018  0.025   0.066      -0.062  0.026  ...  0.015   0.099
# 6       -0.141  0.009   0.264       0.006  0.008  ...  0.022   0.032
# 7        0.018  0.012   0.150      -0.001  0.009  ...  0.014   0.039
# 8       -0.089  0.008   0.220      -0.032  0.005  ...  0.003   0.034
# 9        0.099  0.019   0.208       0.007  0.008  ...  0.008   0.020
# 10      -0.066  0.006   0.354       0.202  0.008  ...  0.012   0.030
# 11      -0.010  0.012   0.209       0.023  0.013  ...  0.026   0.040
# 12       0.089  0.010   0.172      -0.017  0.007  ...  0.027   0.034
# 13       0.068  0.013   0.183      -0.100  0.011  ...  0.017   0.026
#
#     Gap_Ot_mean  CI_Ot  %Asian  Gap_As_mean  CI_As  %American  Gap_Am_mean  \
# 0        -0.038  0.030   0.014        0.011  0.010      0.000          NaN
# 1         0.005  0.006   0.013       -0.009  0.016      0.003        0.088
# 2        -0.067  0.017   0.015        0.029  0.026      0.000          NaN
# 3        -0.027  0.004   0.009        0.132  0.031      0.000          NaN
# 4         0.006  0.005   0.008       -0.106  0.023      0.002       -0.119
# 5         0.150  0.050   0.001       -0.023  0.070      0.002       -0.023
# 6        -0.004  0.006   0.012       -0.163  0.015      0.002        0.061
# 7        -0.030  0.034   0.014        0.208  0.042      0.000          NaN
# 8         0.062  0.016   0.014       -0.080  0.008      0.001        0.032
# 9        -0.065  0.014   0.016        0.084  0.018      0.001       -0.199
# 10        0.057  0.008   0.015        0.091  0.012      0.001       -0.096
# 11        0.192  0.014   0.018       -0.029  0.032      0.000          NaN
# 12        0.017  0.007   0.013       -0.057  0.019      0.003        0.209
# 13       -0.026  0.008   0.015        0.026  0.008      0.001       -0.293
#
#     CI_Am
# 0     NaN
# 1   0.014
# 2     NaN
# 3     NaN
# 4   0.023
# 5   0.027
# 6   0.035
# 7     NaN
# 8   0.005
# 9   0.027
# 10  0.014
# 11    NaN
# 12  0.020
# 13  0.093
#
# [14 rows x 22 columns]

# %%
MIMIC_race.iloc[10]
# Out:
# Unnamed: 0                 8
# diseases          No Finding
# diseases_abbr             NF
# Distance            0.297892
# %White              0.501697
# Gap_W_mean        -0.0657497
# CI_W              0.00588516
# %Black              0.353929
# Gap_B_mean           0.20168
# CI_B              0.00788594
# %Hisp              0.0992829
# Gap_H_mean        -0.0633152
# CI_H               0.0118856
# %Other             0.0295244
# Gap_Ot_mean        0.0574991
# CI_Ot              0.0082426
# %Asian             0.0147523
# Gap_As_mean        0.0907267
# CI_As              0.0116871
# %American        0.000815153
# Gap_Am_mean       -0.0962126
# CI_Am              0.0139108
# Name: 10, dtype: object

# %%
print("Average Distance:",round(MIMIC_race["Distance"].mean(),3))
print("Count white with negative gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_W_mean'] < 0)])-1)
print("Count Black with negative gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_B_mean'] < 0)]))
print("Count Other with negative gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_Ot_mean'] < 0)]))
print("Count Hispanic with negative gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_H_mean'] < 0)])-1)
print("Count Asian with negative gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_As_mean'] < 0)]))
print("Count American with negative gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_Am_mean'] < 0)])-1)
print("--------------------------------------------------")
print("Count white with positive gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_W_mean'] >= 0)]))
print("Count Black with positive gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_B_mean'] >= 0)])-1)
print("Count Other with positive gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_Ot_mean'] >= 0)])-1)
print("Count Hispanic with positive gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_H_mean'] >= 0)]))
print("Count Asian with positive gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_As_mean'] >= 0)])-1)
print("Count American with positive gap:",len(MIMIC_race.loc[(MIMIC_race['Gap_Am_mean'] >= 0)]))
# Out:
# Average Distance: 0.233
# Count white with negative gap: 4
# Count Black with negative gap: 8
# Count Other with negative gap: 7
# Count Hispanic with negative gap: 6
# Count Asian with negative gap: 7
# Count American with negative gap: 4
# --------------------------------------------------
# Count white with positive gap: 9
# Count Black with positive gap: 5
# Count Other with positive gap: 6
# Count Hispanic with positive gap: 7
# Count Asian with positive gap: 6
# Count American with positive gap: 4

# %%
MIMIC_Ins = pd.read_csv("./MIMIC/results/WantI.csv")
round(MIMIC_Ins,3)
# Out:
#     Unnamed: 0                    diseases diseases_abbr  Distance  %Medicare  \
# 0           12                Pneumothorax            Px     0.044      0.476
# 1            0            Airspace Opacity            AO     0.084      0.529
# 2            6                    Fracture            Fr     0.094      0.534
# 3            2                Cardiomegaly            Cd     0.097      0.480
# 4            3               Consolidation            Co     0.099      0.446
# 5            7                 Lung Lesion            LL     0.100      0.532
# 6            5  Enlarged Cardiomediastinum            EC     0.112      0.458
# 7           13             Support Devices            SD     0.131      0.464
# 8           10               Pleural Other            PO     0.136      0.544
# 9           11                   Pneumonia            Pa     0.171      0.549
# 10           9            Pleural Effusion            Ef     0.188      0.549
# 11           4                       Edema            Ed     0.191      0.499
# 12           8                  No Finding            NF     0.224      0.381
# 13           1                 Atelectasis             A     0.265      0.561
#
#     Gap_C_mean   CI_C  %Other  Gap_O_mean   CI_O  %Medicaid  Gap_A_mean   CI_A
# 0        0.017  0.008   0.474      -0.004  0.007      0.050      -0.027  0.020
# 1        0.030  0.008   0.371       0.000  0.000      0.100      -0.055  0.018
# 2        0.000  0.000   0.353       0.049  0.018      0.113      -0.045  0.028
# 3       -0.008  0.010   0.425       0.079  0.011      0.095      -0.019  0.023
# 4       -0.066  0.020   0.432       0.000  0.000      0.122       0.033  0.015
# 5       -0.031  0.019   0.379       0.069  0.025      0.089       0.000  0.000
# 6       -0.025  0.007   0.448       0.000  0.000      0.094       0.087  0.004
# 7        0.000  0.000   0.464       0.112  0.006      0.072      -0.020  0.007
# 8        0.093  0.054   0.238      -0.043  0.052      0.218      -0.012  0.016
# 9       -0.000  0.001   0.373      -0.010  0.012      0.078       0.161  0.018
# 10       0.088  0.010   0.407       0.000  0.000      0.043      -0.100  0.011
# 11       0.000  0.000   0.397       0.068  0.012      0.104      -0.123  0.012
# 12      -0.217  0.006   0.464       0.003  0.003      0.155       0.007  0.006
# 13       0.098  0.006   0.372       0.000  0.000      0.067      -0.167  0.010

# %%
MIMIC_Ins.iloc[12]
# Out:
# Unnamed: 0                8
# diseases         No Finding
# diseases_abbr            NF
# Distance           0.224145
# %Medicare          0.381492
# Gap_C_mean        -0.217083
# CI_C             0.00611545
# %Other             0.463524
# Gap_O_mean       0.00251267
# CI_O             0.00301741
# %Medicaid          0.154984
# Gap_A_mean       0.00706172
# CI_A             0.00565179
# Name: 12, dtype: object

# %%
print("Average Distance:",round(MIMIC_Ins["Distance"].mean(),3))
print("Count Medicare with negative gap:",len(MIMIC_Ins.loc[(MIMIC_Ins['Gap_C_mean'] < 0)])-1)
print("Count Other with negative gap:",len(MIMIC_Ins.loc[(MIMIC_Ins['Gap_O_mean'] < 0)]))
print("Count MedicAid with negative gap:",len(MIMIC_Ins.loc[(MIMIC_Ins['Gap_A_mean'] < 0)]))
print("-----------------------------------")
print("Count Medicare with Positive gap:",len(MIMIC_Ins.loc[(MIMIC_Ins['Gap_C_mean'] >= 0)]))
print("Count Other with Positive gap:",len(MIMIC_Ins.loc[(MIMIC_Ins['Gap_O_mean'] >= 0)])-1)
print("Count MedicAid with Positive gap:",len(MIMIC_Ins.loc[(MIMIC_Ins['Gap_A_mean'] >= 0)])-1)
# Out:
# Average Distance: 0.138
# Count Medicare with negative gap: 5
# Count Other with negative gap: 3
# Count MedicAid with negative gap: 9
# -----------------------------------
# Count Medicare with Positive gap: 8
# Count Other with Positive gap: 10
# Count MedicAid with Positive gap: 4

# %% [markdown]
# ## Sex All plot

# %%
plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(18,18))

params_CXR, covar = curve_fit(func, MIMIC_sex['%F'], MIMIC_sex['Gap_F_mean'], sigma=MIMIC_sex['CI_F'], absolute_sigma=True)
plt.plot(MIMIC_sex['%F'], func(MIMIC_sex['%F'], params_CXR[0], params_CXR[1]), color='red', label='CXR(slope=1.46)' )
plt.legend()   

params_CXP, covar = curve_fit(func, CXP_sex['%F'], CXP_sex['Gap_F_mean'], sigma=CXP_sex['CI_F'], absolute_sigma=True)
plt.plot(CXP_sex['%F'], func(CXP_sex['%F'], params_CXP[0], params_CXP[1]), color='blue', label='CXP(slope=0.66)' )
plt.legend()   

params_NIH, covar = curve_fit(func, NIH_sex['%F'],NIH_sex['Gap_F_mean'], sigma=NIH_sex['CI_F'], absolute_sigma=True)
plt.plot(NIH_sex['%F'], func(NIH_sex['%F'], params_NIH[0], params_NIH[1]), color='green', label='NIH(slope=0.56)' )
plt.legend()   

#------------------- CXP
plt.scatter(CXP_sex['%F'],CXP_sex['Gap_F_mean'], marker='o',color='blue', label='CXP')
#plt.errorbar(CXP_sex['%F'],CXP_sex['Gap_F_mean'],yerr = CXP_sex['CI_F'],fmt='o',mfc='blue')

for d, x, y in zip(CXP_sex['diseases'], CXP_sex['%F'], CXP_sex['Gap_F_mean']):
    plt.annotate(diseases_abbr_CXP[d], color='blue', xy=(x, y), xytext=(-3, 3), textcoords='offset points', ha='right', va='bottom')

diseases_CXP = np.array(len(diseases_abbr_CXP))
sigma_ab = np.sqrt(np.diagonal(covar))   

# plotting the confidence intervals
hires_x = np.linspace(0.278, 0.447, 100)    
bound_upper = func(hires_x, *(params_CXP + sigma_ab))
bound_lower = func(hires_x, *(params_CXP - sigma_ab))
plt.fill_between(hires_x, bound_lower, bound_upper, color = 'blue', alpha = 0.15)
#
    
plt.xlabel("% FEMALE PER DISEASE")
plt.ylabel("TPR DISPARITY")

#--------------------------------------------- MIMIC 
plt.scatter(MIMIC_sex['%F'],MIMIC_sex['Gap_F_mean'], marker='s',color='red', label='CXR')
#plt.errorbar(CXR_sex['%F'],CXR_sex['Gap_F_mean'],yerr = CXR_sex['CI_F'],fmt='o',mfc='green')

# for d, x, y in zip(MIMIC_sex['diseases'], MIMIC_sex['%F'], MIMIC_sex['Gap_F_mean']):
#      plt.annotate(diseases_abbr_CXR[d], color='red', xy=(x, y), xytext=(-3, 3), textcoords='offset points', ha='left', va='bottom')
    


diseases_CXR = np.array(len(diseases_abbr_CXR))
sigma_ab = np.sqrt(np.diagonal(covar))   

# plotting the confidence intervals
hires_x = np.linspace(0.333, 0.536, 100)    
bound_upper = func(hires_x, *(params_CXR + sigma_ab))
bound_lower = func(hires_x, *(params_CXR - sigma_ab))
plt.fill_between(hires_x, bound_lower, bound_upper, color = 'red', alpha = 0.15)
#
    
plt.xlabel("% FEMALE PER DISEASE")
plt.ylabel("TPR DISPARITY")
#plt.legend('NIH (slope=' + str(round(params_NIH[0], 2)) + ')')   




#--------------------------------------- 'NIH'
plt.scatter(NIH_sex['%F'],NIH_sex['Gap_F_mean'], marker='*',color='green', label='NIH')
#plt.errorbar(NIH_sex['%F'],NIH_sex['Gap_F_mean'],yerr = NIH_sex['CI_F'],fmt='*',mfc='red')

for d, x, y in zip( NIH_sex['diseases'], NIH_sex['%F'], NIH_sex['Gap_F_mean']):
    plt.annotate(diseases_abbr_NIH[d], color='green', xy=(x, y), xytext=(-3, 3), textcoords='offset points', ha='left', va='bottom')


diseases_NIH = np.array(len(diseases_abbr_NIH))
sigma_ab = np.sqrt(np.diagonal(covar))   

# plotting the confidence intervals
hires_x = np.linspace(0.36, 0.885, 100)    
bound_upper = func(hires_x, *(params_NIH + sigma_ab))
bound_lower = func(hires_x, *(params_NIH - sigma_ab))
plt.fill_between(hires_x, bound_lower, bound_upper, color = 'green', alpha = 0.15)
#
    
plt.xlabel("% FEMALE PER DISEASE")
plt.ylabel("TPR DISPARITY")

print("CXR curvefit parameters",params_CXR)
print("CXP curvefit parameters",params_CXP)
print("NIH curvefit parameters",params_NIH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-f3dae800cfa1> in <module>
#       3 plt.figure(figsize=(18,18))
#       4
# ----> 5 params_CXR, covar = curve_fit(func, MIMIC_sex['%F'], MIMIC_sex['Gap_F_mean'], sigma=MIMIC_sex['CI_F'], absolute_sigma=True)
#       6 plt.plot(MIMIC_sex['%F'], func(MIMIC_sex['%F'], params_CXR[0], params_CXR[1]), color='red', label='CXR(slope=1.46)' )
#       7 plt.legend()
#
# NameError: name 'func' is not defined
